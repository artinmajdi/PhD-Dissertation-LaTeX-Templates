# %%
import os,sys
from glob import glob
import numpy as np
import matplotlib.pyplot as plt
# import skimage

# %%
dir = '/groups/jjrodrig/projects/datasets/taxonomy_aim1_1/CUB_200_2011'

# %%
# path = f'{dir}/'
glob(f'{dir}/README.txt')
# Out:
# ['/groups/jjrodrig/projects/datasets/taxonomy_aim1_1/CUB_200_2011/README.txt']

# %%
# files[0]
# Out:
# '/groups/jjrodrig/projects/datasets/taxonomy_aim1_1/CUB_200_2011/segmentations/092.Nighthawk/Nighthawk_0032_795333.png'

# %%
# im = plt.imread(files[0])

# %%
# plt.imshow(im,cmap='gray')

# %%
# from ebird.api import get_taxonomy, get_taxonomy_forms
# from ebird.api import find_regions, list_regions, list_species, list_hotspots

# %%
# get_taxonomy(token=2,species='nigripes')
# get_taxonomy(token=2,)
# list_species()
# Out:
# []
